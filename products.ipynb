# %% [markdown]
# <a href="https://colab.research.google.com/github/MABD-KARIM/retail_batch_gcp/blob/main/products.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
# !pip install shortuuid
from shortuuid import ShortUUID
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: shortuuid in /usr/local/lib/python3.10/dist-packages (1.0.11)

# %%
brands = ["HP","Acer","Dell","Visio","Thinkpad","Mac Pro","Asus"]
rams = ["X32","X64","X128"]
disks=["SSD","HDD"]
header = ["ProdId","ProdCode","ProdBrand","ProdCost","ProdPrice"]
costs = [300,400,500,600,700,800]
prices=[900,1000,1200,1500,2000,2500]

# %%
from random import choice
with open("products.csv", mode="w") as file:
  writer = csv.writer(file)
  writer.writerow(header)
  for id in range(1,41):
    row=[]
    row.append(id)
    brand = choice(brands)
    ram = choice(rams)
    disk = choice(disks)
    x = ShortUUID().random(length=5)
    code = brand+"-"+ram+"-"+disk+"-"+str(x)
    row.append(code)
    row.append(brand)
    cost = choice(costs)
    row.append(cost)
    price=choice(prices)
    row.append(price)
    writer.writerow(row)

# %%
import pandas as pd

df=pd.read_csv("products.csv")
df.head(10)
# Out:
#    ProdId                ProdCode ProdBrand  ProdCost  ProdPrice
# 0       1      Dell-X64-HDD-JBuQd      Dell       800        900
# 1       2  Thinkpad-X32-HDD-ANFhX  Thinkpad       300       1000
# 2       3        HP-X64-SSD-4QPXT        HP       800       2500
# 3       4     Dell-X128-SSD-hF8aH      Dell       600       1500
# 4       5   Mac Pro-X64-HDD-L4qbZ   Mac Pro       700        900
# 5       6     Visio-X32-SSD-LoTQG     Visio       300       2500
# 6       7     Acer-X128-SSD-3Zwxj      Acer       300       1200
# 7       8      Asus-X64-SSD-HGxpg      Asus       800       2000
# 8       9      Acer-X64-HDD-4kstR      Acer       300        900
# 9      10        HP-X32-SSD-88CTd        HP       600       1000
